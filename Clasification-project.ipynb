# %%
from acquire import get_telco_data
from prepare import prep_telco
import explore
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-99f39ebe208f> in <module>
#       1 from acquire import get_telco_data
# ----> 2 from prepare import prep_telco
#       3 import explore
#
# ImportError: cannot import name 'prep_telco' from 'prepare' (/Users/mcrob99/codeup-data-science/classification-exercises/prepare.py)

# %%
telco = get_telco_data()

# %%
telco.head().T
# Out:
#                                    0           1           2           3  \
# Unnamed: 0                         0           1           2           3
# customer_id               0002-ORFBO  0003-MKNFE  0004-TLHLJ  0011-IGKFF
# gender                        Female        Male        Male        Male
# senior_citizen                     0           0           0           1
# partner                          Yes          No          No         Yes
# dependents                       Yes          No          No          No
# tenure                             9           9           4          13
# phone_service                    Yes         Yes         Yes         Yes
# multiple_lines                    No         Yes          No          No
# internet_service_type_id           1           1           2           2
# online_security                   No          No          No          No
# online_backup                    Yes          No          No         Yes
# ...
